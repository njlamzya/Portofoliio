# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# #EDA

# %%
import pandas as pd

df = pd.read_csv('/content/Supermarket.csv')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Product  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                 STARS GIFT TAPE         24
#
#       InvoiceDate  UnitPrice  CustomerID Country
# 0  12/1/2010 8:45       3.75     12583.0  France
# 1  12/1/2010 8:45       3.75     12583.0  France
# 2  12/1/2010 8:45       3.75     12583.0  France
# 3  12/1/2010 8:45       0.85     12583.0  France
# 4  12/1/2010 8:45       0.65     12583.0  France

# %%
df.shape
# Out:
# (8557, 8)

# %%
import matplotlib.pyplot as plt

missing_counts = df.isnull().sum()

plt.figure(figsize=(10, 5))
ax = missing_counts.plot(kind='bar')

plt.title('Jumlah Nilai Null pada Setiap Kolom')
plt.xlabel('Kolom')
plt.ylabel('Jumlah')
plt.xticks(rotation=45, ha='right')

# Tambahkan angka di atas setiap bar
for p in ax.patches:
    ax.annotate(
        str(int(p.get_height())),
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center',
        va='bottom',
        fontsize=9,
        xytext=(0, 2),
        textcoords='offset points'
    )

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Konversi InvoiceDate ke datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], errors='coerce')
df = df.dropna(subset=['InvoiceDate'])

# Histogram Frekuensi Produk Teratas
top_products = df['Product'].value_counts().nlargest(10)

plt.figure(figsize=(12, 6))
ax = sns.barplot(
    x=top_products.values,
    y=top_products.index,
    palette='viridis'
)

plt.title("10 Produk yang Paling Sering Dibeli")
plt.xlabel("Jumlah Transaksi")

# Tambahkan angka di ujung bar
for i, v in enumerate(top_products.values):
    ax.text(v + 0.5, i, str(v), va='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2518943085.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
plt.figure(figsize=(12,5))
plt.plot(
    trx_per_month.index,
    trx_per_month.values,
    marker='o',
    linewidth=1.8
)

plt.title("Jumlah Transaksi per Bulan")
plt.xlabel("Bulan")
plt.ylabel("Jumlah Transaksi")
plt.xticks(rotation=45)
plt.grid(alpha=0.3)

# Tambahkan angka dengan offset ke atas
for x, y in zip(trx_per_month.index, trx_per_month.values):
    plt.annotate(
        str(y),
        (x, y),
        textcoords="offset points",
        xytext=(0, 6),   # ⬅️ jarak ke atas
        ha='center',
        fontsize=9
    )

plt.tight_layout()
plt.show()

# %%
quantity_stats = {
    'Mean': df['Quantity'].mean(),
    'Mode': df['Quantity'].mode()[0],
    'Q1': df['Quantity'].quantile(0.25),
    'Median': df['Quantity'].quantile(0.50),
    'Q3': df['Quantity'].quantile(0.75)
}

quantity_stats
# Out:
# {'Mean': np.float64(12.91106696272058),
#  'Mode': np.int64(12),
#  'Q1': np.float64(5.0),
#  'Median': np.float64(10.0),
#  'Q3': np.float64(12.0)}

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Product                object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %% [markdown]
# #Pra-pemrosesan

# %%
df = df.dropna(subset=['CustomerID'])

# %%
df.shape
# Out:
# (8491, 8)

# %%
duplicate_rows = df.duplicated()
num_duplicates = duplicate_rows.sum()

print(f"Jumlah data duplikat: {num_duplicates}")
# Out:
# Jumlah data duplikat: 16

# %%
df[df.duplicated(keep=False)]
# Out:
#      InvoiceNo StockCode                              Product  Quantity  \
# 1772    547194     22895  SET OF 2 TEA TOWELS APPLE AND PEARS         1
# 1779    547194     22554     PLASTERS IN TIN WOODLAND ANIMALS         1
# 1784    547194     22554     PLASTERS IN TIN WOODLAND ANIMALS         1
# 1807    547194     22895  SET OF 2 TEA TOWELS APPLE AND PEARS         1
# 2545    552826     82583                 HOT BATHS METAL SIGN         4
# 2550    552826     82583                 HOT BATHS METAL SIGN         4
# 5766    569332     22328   ROUND SNACK BOXES SET OF 4 FRUITS          1
# 5772    569332     22553               PLASTERS IN TIN SKULLS         1
# 5788    569332     23206               LUNCH BAG APPLE DESIGN         1
# 5790    569332     22553               PLASTERS IN TIN SKULLS         1
# 5791    569332     22124   SET OF 2 TEA TOWELS PING MICROWAVE         1
# 5792    569332     21035      SET/2 RED RETROSPOT TEA TOWELS          1
# 5794    569332     22124   SET OF 2 TEA TOWELS PING MICROWAVE         1
# 5798    569332     22629                  SPACEBOY LUNCH BOX          1
# 5802    569332     22328   ROUND SNACK BOXES SET OF 4 FRUITS          1
# 5804    569332     23206               LUNCH BAG APPLE DESIGN         1
# 5805    569332     21035      SET/2 RED RETROSPOT TEA TOWELS          1
# 5807    569332     22629                  SPACEBOY LUNCH BOX          1
# 6773   C574095     22326  ROUND SNACK BOXES SET OF4 WOODLAND         -1
# 6774   C574095     22326  ROUND SNACK BOXES SET OF4 WOODLAND         -1
# 6880    574506     23085         ANTIQUE SILVER BAUBLE LAMP           3
# 6893    574506     23085         ANTIQUE SILVER BAUBLE LAMP           3
# 7056    575519     23506         MINI PLAYING CARDS SPACEBOY         20
# 7057    575519     23506         MINI PLAYING CARDS SPACEBOY         20
# 7126    575661     22571         ROCKING HORSE RED CHRISTMAS          3
# 7131    575661     22571         ROCKING HORSE RED CHRISTMAS          3
# 7168    575692     21818             GLITTER HEART DECORATION         1
# 7197    575692     21818             GLITTER HEART DECORATION         1
# 7894    578541     23116      VEGETABLE GARDEN CHOPPING BOARD         2
# 7895    578541     23115         RED APPLES CHOPPING BOARD            2
# 7897    578541     23116      VEGETABLE GARDEN CHOPPING BOARD         2
# 7898    578541     23115         RED APPLES CHOPPING BOARD            2
#
#              InvoiceDate  UnitPrice  CustomerID Country
# 1772 2011-03-21 12:42:00       2.95     12637.0  France
# 1779 2011-03-21 12:42:00       1.65     12637.0  France
# 1784 2011-03-21 12:42:00       1.65     12637.0  France
# 1807 2011-03-21 12:42:00       2.95     12637.0  France
# 2545 2011-05-11 13:20:00       2.10     14277.0  France
# 2550 2011-05-11 13:20:00       2.10     14277.0  France
# 5766 2011-10-03 13:46:00       2.95     12637.0  France
# 5772 2011-10-03 13:46:00       1.65     12637.0  France
# 5788 2011-10-03 13:46:00       1.65     12637.0  France
# 5790 2011-10-03 13:46:00       1.65     12637.0  France
# 5791 2011-10-03 13:46:00       2.95     12637.0  France
# 5792 2011-10-03 13:46:00       3.25     12637.0  France
# 5794 2011-10-03 13:46:00       2.95     12637.0  France
# 5798 2011-10-03 13:46:00       1.95     12637.0  France
# 5802 2011-10-03 13:46:00       2.95     12637.0  France
# 5804 2011-10-03 13:46:00       1.65     12637.0  France
# 5805 2011-10-03 13:46:00       3.25     12637.0  France
# 5807 2011-10-03 13:46:00       1.95     12637.0  France
# 6773 2011-11-03 09:54:00       2.95     12674.0  France
# 6774 2011-11-03 09:54:00       2.95     12674.0  France
# 6880 2011-11-04 13:24:00      10.40     12577.0  France
# 6893 2011-11-04 13:24:00      10.40     12577.0  France
# 7056 2011-11-10 10:53:00       0.42     12682.0  France
# 7057 2011-11-10 10:53:00       0.42     12682.0  France
# 7126 2011-11-10 14:39:00       0.85     12617.0  France
# 7131 2011-11-10 14:39:00       0.85     12617.0  France
# 7168 2011-11-10 16:27:00       0.39     12508.0  France
# 7197 2011-11-10 16:27:00       0.39     12508.0  France
# 7894 2011-11-24 15:01:00       4.95     14277.0  France
# 7895 2011-11-24 15:01:00       4.95     14277.0  France
# 7897 2011-11-24 15:01:00       4.95     14277.0  France
# 7898 2011-11-24 15:01:00       4.95     14277.0  France

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (8475, 8)

# %%
# Cek apakah ada nilai negatif di kolom Quantity dan UnitPrice
(df['Quantity'] < 0).any(), (df['UnitPrice'] < 0).any()
# Out:
# (np.True_, np.False_)

# %%
df = df[(df['Quantity'] > 0)]
df = df[(df['UnitPrice'] > 0)]

# %%
df.shape
# Out:
# (8326, 8)

# %%
# Total transaksi per item
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# %% [markdown]
# #Transformasi Data

# %%
hasil_agregasi = df.groupby('Product').agg(
    keterlibatan=("InvoiceNo","nunique"),
    jumlah_riil=("Quantity","sum")
).reset_index().sort_values(by="keterlibatan",ascending=False)

hasil_agregasi
# Out:
#                                   Product  keterlibatan  jumlah_riil
# 964                               POSTAGE           300          825
# 972                    RABBIT NIGHT LIGHT            73         4000
# 1046        RED TOADSTOOL LED NIGHT LIGHT            70         1291
# 946      PLASTERS IN TIN WOODLAND ANIMALS            67         1143
# 941        PLASTERS IN TIN CIRCUS PARADE             66         1144
# ...                                   ...           ...          ...
# 24       3 RAFFIA RIBBONS 50'S CHRISTMAS              1           10
# 22             3 HOOK HANGER MAGIC GARDEN             1           12
# 18     16 PIECE CUTLERY SET PANTRY DESIGN             1            2
# 17    15CM CHRISTMAS GLASS BALL 20 LIGHTS             1            8
# 1511       WOODLAND SMALL BLUE FELT HEART             1           12
#
# [1544 rows x 3 columns]

# %%
hasil_agregasi.to_csv('hasil_agregasi.csv', index=False)

# %%
hasil_agregasi['keterlibatan'].median()
# Out:
# 2.0

# %%
hasil_agregasi['jumlah_riil'].median()
# Out:
# 24.0

# %%
agregasi = hasil_agregasi[(hasil_agregasi['keterlibatan'] > 2) & (hasil_agregasi['jumlah_riil'] > 24)]

# %%
agregasi
# Out:
#                                  Product  keterlibatan  jumlah_riil
# 964                              POSTAGE           300          825
# 972                   RABBIT NIGHT LIGHT            73         4000
# 1046       RED TOADSTOOL LED NIGHT LIGHT            70         1291
# 946     PLASTERS IN TIN WOODLAND ANIMALS            67         1143
# 941       PLASTERS IN TIN CIRCUS PARADE             66         1144
# ...                                  ...           ...          ...
# 1531                WRAP POPPIES  DESIGN             3           75
# 1528                 WRAP I LOVE LONDON              3          100
# 28                 36 DOILIES DOLLY GIRL             3           36
# 27    3 TRADITIONAl BISCUIT CUTTERS  SET             3           36
# 1237    SET/20 STRAWBERRY PAPER NAPKINS              3           36
#
# [582 rows x 3 columns]

# %%
agregasi.to_csv('agregasi.csv', index=False)

# %%
df = df.merge(agregasi[['Product', 'keterlibatan', 'jumlah_riil']], on='Product', how='left')
df = df.dropna(subset=['keterlibatan'])

# %%
df
# Out:
#      InvoiceNo StockCode                          Product  Quantity  \
# 0       536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1       536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2       536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 4       536370     21883                 STARS GIFT TAPE         24
# 5       536370     10002      INFLATABLE POLITICAL GLOBE         48
# ...        ...       ...                              ...       ...
# 8321    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 8322    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 8323    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 8324    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 8325    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID Country  TotalPrice  \
# 0    2010-12-01 08:45:00       3.75     12583.0  France       90.00
# 1    2010-12-01 08:45:00       3.75     12583.0  France       90.00
# 2    2010-12-01 08:45:00       3.75     12583.0  France       45.00
# 4    2010-12-01 08:45:00       0.65     12583.0  France       15.60
# 5    2010-12-01 08:45:00       0.85     12583.0  France       40.80
# ...                  ...        ...         ...     ...         ...
# 8321 2011-12-09 12:50:00       0.85     12680.0  France       10.20
# 8322 2011-12-09 12:50:00       2.10     12680.0  France       12.60
# 8323 2011-12-09 12:50:00       4.15     12680.0  France       16.60
# 8324 2011-12-09 12:50:00       4.15     12680.0  France       16.60
# 8325 2011-12-09 12:50:00       4.95     12680.0  France       14.85
#
#       keterlibatan  jumlah_riil
# 0             40.0        362.0
# 1             37.0        316.0
# 2             38.0        340.0
# 4             13.0        312.0
# 5              8.0        372.0
# ...            ...          ...
# 8321           8.0        132.0
# 8322          19.0        200.0
# 8323          28.0        160.0
# 8324          12.0        118.0
# 8325          30.0        192.0
#
# [6667 rows x 11 columns]

# %%
df.to_csv('df_agregasi.csv', index=False)

# %% [markdown]
# #RFM

# %%
# Tanggal referensi = tanggal terakhir transaksi
max_date = df['InvoiceDate'].max()

# Fungsi untuk menghitung Recency
def recency_func(tanggal):
    return (max_date - tanggal.max()).days

# Hitung nilai RFM
rfm = df.groupby('CustomerID').agg({
    'InvoiceDate': recency_func,    # Recency
    'InvoiceNo': 'nunique',         # Frequency
    'TotalPrice': 'sum'             # Monetary
}).reset_index()

# Ganti nama kolom
rfm.columns = ['CustomerID', 'Recency', 'Frequency', 'Monetary']

rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0     12413.0       66          3    652.10
# 1     12437.0        1         18   4413.42
# 2     12441.0      366          1     63.90
# 3     12488.0        9          3   1033.46
# 4     12489.0      335          1    266.28

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm[['Recency', 'Frequency', 'Monetary']])

# %% [markdown]
# #K-Means

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

sse = []

for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(rfm_scaled)
    sse.append(kmeans.inertia_)

plt.figure(figsize=(6,4))
plt.plot(range(1, 10), sse, marker='o', linewidth=1.8)

plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of Clusters')
plt.ylabel('SSE')

# Tambahkan angka SSE dengan offset
for x, y in zip(range(1, 10), sse):
    plt.annotate(
        f'{y:.0f}',          # tanpa desimal
        (x, y),
        textcoords="offset points",
        xytext=(0, 8),       # geser ke atas
        ha='center',
        fontsize=9
    )

plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import silhouette_score

sil_scores = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(rfm_scaled)
    sil = silhouette_score(rfm_scaled, labels)
    sil_scores.append(sil)
    print("k =", k, " | Silhouette =", sil)
# Out:
# k = 2  | Silhouette = 0.6191411590543493
# k = 3  | Silhouette = 0.5996039595308218
# k = 4  | Silhouette = 0.49073670607217457
# k = 5  | Silhouette = 0.5079267571304336
# k = 6  | Silhouette = 0.3851873224568369
# k = 7  | Silhouette = 0.39750345589212294
# k = 8  | Silhouette = 0.42865431225847184
# k = 9  | Silhouette = 0.4195142129025403

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
rfm['Cluster'] = kmeans.fit_predict(rfm_scaled)

# %%
cluster_summary = rfm.groupby('Cluster').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'Monetary': 'mean',
    'CustomerID': 'count'
}).rename(columns={'CustomerID': 'Count'}).round(2)

print(cluster_summary)
# Out:
#          Recency  Frequency  Monetary  Count
# Cluster
# 0          42.82       3.68   1306.13     62
# 1          13.75      16.62  10523.47      8
# 2         297.29       1.06    196.37     17

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=rfm, x='Recency', y='Monetary', hue='Cluster', palette='tab10')
plt.title('Customer Segmentation based on RFM')
plt.show()

# %%
df = df.merge(rfm[['CustomerID', 'Cluster']], on='CustomerID', how='left')

# %%
df
# Out:
#      InvoiceNo StockCode                          Product  Quantity  \
# 0       536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1       536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2       536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3       536370     21883                 STARS GIFT TAPE         24
# 4       536370     10002      INFLATABLE POLITICAL GLOBE         48
# ...        ...       ...                              ...       ...
# 6662    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 6663    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 6664    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 6665    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 6666    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID Country  TotalPrice  \
# 0    2010-12-01 08:45:00       3.75     12583.0  France       90.00
# 1    2010-12-01 08:45:00       3.75     12583.0  France       90.00
# 2    2010-12-01 08:45:00       3.75     12583.0  France       45.00
# 3    2010-12-01 08:45:00       0.65     12583.0  France       15.60
# 4    2010-12-01 08:45:00       0.85     12583.0  France       40.80
# ...                  ...        ...         ...     ...         ...
# 6662 2011-12-09 12:50:00       0.85     12680.0  France       10.20
# 6663 2011-12-09 12:50:00       2.10     12680.0  France       12.60
# 6664 2011-12-09 12:50:00       4.15     12680.0  France       16.60
# 6665 2011-12-09 12:50:00       4.15     12680.0  France       16.60
# 6666 2011-12-09 12:50:00       4.95     12680.0  France       14.85
#
#       keterlibatan  jumlah_riil  Cluster
# 0             40.0        362.0        1
# 1             37.0        316.0        1
# 2             38.0        340.0        1
# 3             13.0        312.0        1
# 4              8.0        372.0        1
# ...            ...          ...      ...
# 6662           8.0        132.0        0
# 6663          19.0        200.0        0
# 6664          28.0        160.0        0
# 6665          12.0        118.0        0
# 6666          30.0        192.0        0
#
# [6667 rows x 12 columns]

# %%
df.to_csv('label cluster.csv', index=False)

# %% [markdown]
# #FP-Growth

# %%
# subset per cluster
cluster_0 = df[df['Cluster'] == 0]
cluster_1 = df[df['Cluster'] == 1]
cluster_2 = df[df['Cluster'] == 2]

# %%
# mengelompokkan item per transaksi
transactions_cluster0 = cluster_0.groupby('InvoiceNo')['Product'].apply(list)
transactions_cluster1 = cluster_1.groupby('InvoiceNo')['Product'].apply(list)
transactions_cluster2 = cluster_2.groupby('InvoiceNo')['Product'].apply(list)

# %%
transactions_cluster0.shape
# Out:
# (228,)

# %%
transactions_cluster1.shape
# Out:
# (133,)

# %%
transactions_cluster2.shape
# Out:
# (18,)

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules

# cluster 0
te = TransactionEncoder()
te_ary = te.fit(transactions_cluster0).transform(transactions_cluster0)
df_cluster0_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# FP-Growth cluster 0
frequent_items_0 = fpgrowth(df_cluster0_encoded, min_support=0.06)
rules_0 = association_rules(frequent_items_0, metric="lift", min_threshold=1)

# %%
frequent_items_0.shape
# Out:
# (160, 2)

# %%
rules_0.shape
# Out:
# (272, 14)

# %%
rules_0.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0       (226)       (339)            0.100877            0.776316  0.078947
# 1       (339)       (226)            0.776316            0.100877  0.078947
# 2       (226)       (236)            0.100877            0.131579  0.070175
# 3       (236)       (226)            0.131579            0.100877  0.070175
# 4       (226)       (231)            0.100877            0.140351  0.065789
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.782609  1.008106               1.0  0.000635    1.028947
# 1    0.101695  1.008106               1.0  0.000635    1.000910
# 2    0.695652  5.286957               1.0  0.056902    2.853383
# 3    0.533333  5.286957               1.0  0.056902    1.926692
# 4    0.652174  4.646739               1.0  0.051631    2.471491
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 0       0.008943  0.098901   0.028133    0.442152
# 1       0.035948  0.098901   0.000909    0.442152
# 2       0.901829  0.432432   0.649539    0.614493
# 3       0.933712  0.432432   0.480976    0.614493
# 4       0.872846  0.375000   0.595386    0.560462

# %%
# Mengambil nama produk
product_map = df['Product'].to_dict()

def map_product_names(itemset):
    return [product_map.get(i, str(i)) for i in itemset]

rules_0['antecedents'] = rules_0['antecedents'].apply(map_product_names)
rules_0['consequents'] = rules_0['consequents'].apply(map_product_names)

rules_0 = rules_0[['antecedents', 'consequents', 'support', 'confidence', 'lift']]

# %%
top10_rules0 = (
    rules_0.sort_values(by='lift', ascending=False).head(10)
)
top10_rules0
# Out:
#                                            antecedents  \
# 234                      [BIG DOUGHNUT FRIDGE MAGNETS]
# 231  [RED RETROSPOT MINI CASES, SET OF SALT AND PEP...
# 263                               [WOODLAND  STICKERS]
# 262                     [COFFEE MUG CAT + BIRD DESIGN]
# 266                     [COFFEE MUG CAT + BIRD DESIGN]
# 265  [PACK OF 72 RETROSPOT CAKE CASES, WOODLAND  ST...
# 267                               [WOODLAND  STICKERS]
# 264  [COFFEE MUG CAT + BIRD DESIGN, PACK OF 72 RETR...
# 230  [RED RETROSPOT MINI CASES, BIG DOUGHNUT FRIDGE...
# 218                      [BIG DOUGHNUT FRIDGE MAGNETS]
#
#                                            consequents   support  confidence  \
# 234  [RED RETROSPOT MINI CASES, SET OF SALT AND PEP...  0.065789    0.625000
# 231                      [BIG DOUGHNUT FRIDGE MAGNETS]  0.065789    0.937500
# 263                     [COFFEE MUG CAT + BIRD DESIGN]  0.096491    0.880000
# 262                               [WOODLAND  STICKERS]  0.096491    0.956522
# 266  [PACK OF 72 RETROSPOT CAKE CASES, WOODLAND  ST...  0.061404    0.608696
# 265                     [COFFEE MUG CAT + BIRD DESIGN]  0.061404    0.875000
# 267  [COFFEE MUG CAT + BIRD DESIGN, PACK OF 72 RETR...  0.061404    0.560000
# 264                               [WOODLAND  STICKERS]  0.061404    0.933333
# 230                [SET OF SALT AND PEPPER TOADSTOOLS]  0.065789    0.833333
# 218                [SET OF SALT AND PEPPER TOADSTOOLS]  0.087719    0.833333
#
#          lift
# 234  8.906250
# 231  8.906250
# 263  8.723478
# 262  8.723478
# 266  8.673913
# 265  8.673913
# 267  8.512000
# 264  8.512000
# 230  8.260870
# 218  8.260870

# %%
rules_0.to_csv('rules 0.csv', index=False)

# %%
# Cluster 1
te = TransactionEncoder()
te_ary = te.fit(transactions_cluster1).transform(transactions_cluster1)
df_cluster1_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# FP-Growth cluster 1
frequent_items_1 = fpgrowth(df_cluster1_encoded, min_support=0.06)
rules_1 = association_rules(frequent_items_1, metric="lift", min_threshold=1)

# %%
frequent_items_1.shape
# Out:
# (321, 2)

# %%
rules_1.shape
# Out:
# (826, 14)

# %%
rules_1.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0       (283)       (318)            0.834586            0.233083  0.225564
# 1       (318)       (283)            0.233083            0.834586  0.225564
# 2       (201)       (318)            0.255639            0.233083  0.060150
# 3       (318)       (201)            0.233083            0.255639  0.060150
# 4  (201, 283)       (318)            0.203008            0.233083  0.060150
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.270270  1.159547               1.0  0.031036    1.050961
# 1    0.967742  1.159547               1.0  0.031036    5.127820
# 2    0.235294  1.009488               1.0  0.000565    1.002892
# 3    0.258065  1.009488               1.0  0.000565    1.003269
# 4    0.296296  1.271207               1.0  0.012833    1.089830
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 0       0.831818  0.267857   0.048490    0.619006
# 1       0.179412  0.267857   0.804985    0.619006
# 2       0.012626  0.140351   0.002884    0.246679
# 3       0.012255  0.140351   0.003258    0.246679
# 4       0.267689  0.160000   0.082426    0.277180

# %%
rules_1['antecedents'] = rules_1['antecedents'].apply(map_product_names)
rules_1['consequents'] = rules_1['consequents'].apply(map_product_names)

rules_1 = rules_1[['antecedents', 'consequents', 'support', 'confidence', 'lift']]

# %%
top10_rules1 = (
    rules_1.sort_values(by='lift', ascending=False).head(10)
)
top10_rules1
# Out:
#                                            antecedents  \
# 307                     [FELTCRAFT PRINCESS LOLA DOLL]
# 302  [CLOTHES PEGS RETROSPOT PACK 24 , RED TOADSTOO...
# 687                             [BASKET OF TOADSTOOLS]
# 682  [EDWARDIAN PARASOL BLACK, BLACK RECORD COVER F...
# 570                        [EDWARDIAN PARASOL NATURAL]
# 571                                          [POSTAGE]
# 300                  [CLOTHES PEGS RETROSPOT PACK 24 ]
# 305                  [CLOTHES PEGS RETROSPOT PACK 24 ]
# 301                     [FELTCRAFT PRINCESS LOLA DOLL]
# 304  [RED TOADSTOOL LED NIGHT LIGHT, FELTCRAFT PRIN...
#
#                                            consequents  support  confidence  \
# 307  [CLOTHES PEGS RETROSPOT PACK 24 , RED TOADSTOO...  0.06015    0.888889
# 302                     [FELTCRAFT PRINCESS LOLA DOLL]  0.06015    0.800000
# 687  [EDWARDIAN PARASOL BLACK, BLACK RECORD COVER F...  0.06015    0.888889
# 682                             [BASKET OF TOADSTOOLS]  0.06015    0.800000
# 570                                          [POSTAGE]  0.06015    1.000000
# 571                        [EDWARDIAN PARASOL NATURAL]  0.06015    0.666667
# 300                     [FELTCRAFT PRINCESS LOLA DOLL]  0.06015    0.727273
# 305  [RED TOADSTOOL LED NIGHT LIGHT, FELTCRAFT PRIN...  0.06015    0.727273
# 301                  [CLOTHES PEGS RETROSPOT PACK 24 ]  0.06015    0.888889
# 304                  [CLOTHES PEGS RETROSPOT PACK 24 ]  0.06015    0.888889
#
#           lift
# 307  11.822222
# 302  11.822222
# 687  11.822222
# 682  11.822222
# 570  11.083333
# 571  11.083333
# 300  10.747475
# 305  10.747475
# 301  10.747475
# 304  10.747475

# %%
rules_1.to_csv('rules 1.csv', index=False)

# %%
# Cluster 2
te = TransactionEncoder()
te_ary = te.fit(transactions_cluster2).transform(transactions_cluster2)
df_cluster2_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# FP-Growth cluster 1
frequent_items_2 = fpgrowth(df_cluster2_encoded, min_support=0.06)
rules_2 = association_rules(frequent_items_2, metric="lift", min_threshold=1)

# %%
frequent_items_2.shape
# Out:
# (128, 2)

# %%
rules_2.shape
# Out:
# (838, 14)

# %%
rules_2.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0        (18)        (91)            0.111111            0.666667  0.111111
# 1        (91)        (18)            0.666667            0.111111  0.111111
# 2        (73)        (91)            0.166667            0.666667  0.166667
# 3        (91)        (73)            0.666667            0.166667  0.166667
# 4        (73)       (116)            0.166667            0.111111  0.111111
#
#    confidence  lift  representativity  leverage  conviction  zhangs_metric  \
# 0    1.000000   1.5               1.0  0.037037         inf          0.375
# 1    0.166667   1.5               1.0  0.037037    1.066667          1.000
# 2    1.000000   1.5               1.0  0.055556         inf          0.400
# 3    0.250000   1.5               1.0  0.055556    1.111111          1.000
# 4    0.666667   6.0               1.0  0.092593    2.666667          1.000
#
#     jaccard  certainty  kulczynski
# 0  0.166667     1.0000    0.583333
# 1  0.166667     0.0625    0.583333
# 2  0.250000     1.0000    0.625000
# 3  0.250000     0.1000    0.625000
# 4  0.666667     0.6250    0.833333

# %%
rules_2['antecedents'] = rules_2['antecedents'].apply(map_product_names)
rules_2['consequents'] = rules_2['consequents'].apply(map_product_names)

rules_2 = rules_2[['antecedents', 'consequents', 'support', 'confidence', 'lift']]

# %%
top10_rules2 = (
    rules_2.sort_values(by='lift', ascending=False).head(10)
)
top10_rules2
# Out:
#                                            antecedents  \
# 835                           [MINI JIGSAW DOLLY GIRL]
# 834                             [MINI JIGSAW SPACEBOY]
# 817      [RETROSPOT LARGE MILK JUG, GUMBALL COAT RACK]
# 816   [PINK  HONEYCOMB PAPER BALL , GUMBALL COAT RACK]
# 815  [ASSORTED COLOUR MINI CASES, RETROSPOT LARGE M...
# 814  [ASSORTED COLOUR MINI CASES, PINK  HONEYCOMB P...
# 813    [ASSORTED COLOUR MINI CASES, GUMBALL COAT RACK]
# 812  [ALARM CLOCK BAKELIKE PINK, RETROSPOT LARGE MI...
# 811  [ALARM CLOCK BAKELIKE PINK, PINK  HONEYCOMB PA...
# 810     [ALARM CLOCK BAKELIKE PINK, GUMBALL COAT RACK]
#
#                                            consequents   support  confidence  \
# 835    [MINI JIGSAW SPACEBOY, TEA PARTY BIRTHDAY CARD]  0.111111         1.0
# 834  [TEA PARTY BIRTHDAY CARD, MINI JIGSAW DOLLY GIRL]  0.111111         1.0
# 817  [ALARM CLOCK BAKELIKE PINK, ASSORTED COLOUR MI...  0.111111         1.0
# 816  [ALARM CLOCK BAKELIKE PINK, ASSORTED COLOUR MI...  0.111111         1.0
# 815  [ALARM CLOCK BAKELIKE PINK, PINK  HONEYCOMB PA...  0.111111         1.0
# 814  [ALARM CLOCK BAKELIKE PINK, RETROSPOT LARGE MI...  0.111111         1.0
# 813  [ALARM CLOCK BAKELIKE PINK, RETROSPOT LARGE MI...  0.111111         1.0
# 812  [PINK  HONEYCOMB PAPER BALL , ASSORTED COLOUR ...  0.111111         1.0
# 811  [ASSORTED COLOUR MINI CASES, RETROSPOT LARGE M...  0.111111         1.0
# 810  [ASSORTED COLOUR MINI CASES, RETROSPOT LARGE M...  0.111111         1.0
#
#      lift
# 835   9.0
# 834   9.0
# 817   9.0
# 816   9.0
# 815   9.0
# 814   9.0
# 813   9.0
# 812   9.0
# 811   9.0
# 810   9.0

# %%
rules_2.to_csv('rules 2.csv', index=False)
